# %%
from sklearn.datasets import load_wine
import pandas as pd
import  numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=load_wine()

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names'])

# %%
print(data.DESCR)
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
#     Ash:                          1.36  3.23    2.36  0.27
# ...

# %%
df=pd.DataFrame(data.data,columns=data.feature_names)

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %%
res=pd.DataFrame(data.target,columns=['result'])

# %%
df=pd.concat([df,res],axis=1)

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  result
# ...

# %%
df.result.unique()
# Out:
# array([0, 1, 2])

# %%
df.isnull().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# result                          0
# dtype: int64

# %%
plt.figure(figsize=(15,15))
df.plot()
plt.show()

# %%
plt.style.use('seaborn')
df.hist(bins=10,figsize=(20,15))
plt.show()
# Out:
# /tmp/ipykernel_154/205627868.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
plt.style.use('seaborn')
df.boxplot(figsize=(20,15))
plt.show()
# Out:
# /tmp/ipykernel_154/3442412269.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
sns.boxplot(data=df,x='alcohol')
# Out:
# <AxesSubplot: xlabel='alcohol'>

# %%
for i in df:
    sns.boxplot(data=df,y=i,color='y')
    plt.show()

# %%
X=pd.DataFrame(data.data,columns=data.feature_names)

# %%
Y=pd.DataFrame(data.target,columns=['result'])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.20,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler

# %%
encoder=StandardScaler()

# %%
x_train_scaled=encoder.fit_transform(x_train)

# %%
x_test_scaled=encoder.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()

# %%
regressor.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
predict=regressor.predict(x_test_scaled)

# %%
from sklearn.metrics import r2_score,confusion_matrix,accuracy_score

# %%
r2_score(y_test,predict)
# Out:
# 0.895348517922006

# %%
#  got accuracy of 89.53%

# %%
max(predict)
# Out:
# array([2.28647406])

# %% [markdown]
# #  Creating pickle module to use it from anywhere

# %%
import pickle

# %%
pickle.dump(encoder,open('enc.pkl','wb'))

# %%
pickle.dump(regressor,open('reg.pkl','wb'))

# %%
enc=pickle.load(open('enc.pkl','rb'))

# %%
l1=[[13.75,1.73,2.41,16.0,89.0,2.60,2.76,0.29,1.81,5.600,1.15,2.90,1320]]

# %%
l1_scaled=enc.transform(l1)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:409: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
enc_pk=pickle.load(open('reg.pkl','rb'))

# %%
prd=enc_pk.predict(l1_scaled)

# %%
prd
# Out:
# array([[0.01486416]])
